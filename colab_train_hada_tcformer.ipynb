# %%
# HADA full five-block Mamba-style training: Runtime > Change runtime type > T4 GPU, then run.
# !pip -q install uv
# %cd /content
# !if [ -d tcformer-test/.git ]; then git -C tcformer-test fetch origin feature/hada-full-mamba && git -C tcformer-test checkout feature/hada-full-mamba && git -C tcformer-test pull --ff-only origin feature/hada-full-mamba; else git clone --branch feature/hada-full-mamba --single-branch https://github.com/CuongDM1806/tcformer-test.git; fi
# %cd /content/tcformer-test
# !git log -1 --oneline
# !grep -E 'riemannian_alignment|sequence_block_types|mamba_d_state|mamba_d_conv|im_tta_steps|im_tta_lr|batch_size' configs/hada_tcformer.yaml
# !uv venv --python 3.10 .venv
# !uv pip install --python .venv/bin/python torch==2.7.1 torchvision==0.22.1 --index-url https://download.pytorch.org/whl/cu126
# !uv pip install --python .venv/bin/python -r requirements.txt
# !.venv/bin/python -c "import torch; print(f'PyTorch: {torch.__version__} | CUDA: {torch.cuda.is_available()} | GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else \"CPU\"}')"
# !PYTHONUNBUFFERED=1 MPLBACKEND=Agg .venv/bin/python -u train_pipeline.py --model hada_tcformer --dataset bcic2a --loso --gpu_id 0
