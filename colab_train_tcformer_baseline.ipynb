# %%
# One-cell Colab baseline: Runtime > Change runtime type > T4 GPU.
# !pip -q install uv
# %cd /content
# !if [ -d tcformer-baseline-bs48/.git ]; then git -C tcformer-baseline-bs48 fetch origin gpl-prototype-alignment && git -C tcformer-baseline-bs48 checkout gpl-prototype-alignment && git -C tcformer-baseline-bs48 restore --source=origin/gpl-prototype-alignment -- configs/tcformer.yaml && git -C tcformer-baseline-bs48 pull --ff-only origin gpl-prototype-alignment; else git clone --branch gpl-prototype-alignment --single-branch https://github.com/CuongDM1806/tcformer-test.git tcformer-baseline-bs48; fi
# %cd /content/tcformer-baseline-bs48
# !uv venv --python 3.10 --clear .venv
# !uv pip install --python .venv/bin/python torch==2.7.1 torchvision==0.22.1 --index-url https://download.pytorch.org/whl/cu126
# !uv pip install --python .venv/bin/python -r requirements.txt
# !grep -A6 '^  bcic2a:' configs/tcformer.yaml
# !.venv/bin/python -c "import torch; print(f'CUDA: {torch.cuda.is_available()} | GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else \"CPU\"}')"
# !PYTHONUNBUFFERED=1 MPLBACKEND=Agg .venv/bin/python -u train_pipeline.py --model tcformer --dataset bcic2a --loso --gpu_id 0
